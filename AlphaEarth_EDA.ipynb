# %%
# import sys
# !{sys.executable} -m pip install earthengine-api geemap numpy matplotlib pandas scikit-learn
# Out:
# ...
#   Using cached earthengine_api-1.6.11-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached geemap-0.36.4-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached geemap-0.36.4-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached google_cloud_storage-3.4.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached google_cloud_storage-3.4.1-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached google_api_python_client-2.184.0-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached google_api_python_client-2.184.0-py3-none-any.whl.metadata (7.0 kB)
# ...
#   Using cached google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached google_auth-2.41.1-py2.py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached google_auth_httplib2-0.2.0-py2.py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached httplib2-0.31.0-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# ...

# %% [markdown]
# # Google Earth Engine - Simple Setup
# Easy authentication and basic usage of Google Earth Engine.

# %%
# Step 1: Import libraries
import ee
import os
import geemap
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# Step 2: Authenticate (this will open a browser)
print("🔐 Authenticating with Google Earth Engine...")
ee.Authenticate()

# Step 3: Initialize
print("🚀 Initializing Google Earth Engine...")
ee.Initialize()
# Out:
# 🔐 Authenticating with Google Earth Engine...
# 🚀 Initializing Google Earth Engine...
# 🚀 Initializing Google Earth Engine...

# %%
# Define Austin area
austin = ee.Geometry.Rectangle([-98.0, 30.1, -97.5, 30.5], None, False)

# Load AlphaEarth data
embeddings = ee.ImageCollection('GOOGLE/SATELLITE_EMBEDDING/V1/ANNUAL')
img = (embeddings
       .filterDate(ee.Date.fromYMD(2023, 1, 1), ee.Date.fromYMD(2024, 1, 1))
       .filterBounds(austin)
       .mosaic()
       .clip(austin))

# Create map
Map = geemap.Map(center=[30.2672, -97.7431], zoom=10)

# Add AlphaEarth as RGB (bands A01, A16, A09)
Map.addLayer(
    img.select(['A01','A16','A09']),
    {'min': -0.3, 'max': 0.3},
    'AlphaEarth RGB'
)

# Add Austin boundary
Map.addLayer(austin, {'color': 'blue'}, 'Austin')

# Show the map
Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[30.2672, -97.7431], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topr…
